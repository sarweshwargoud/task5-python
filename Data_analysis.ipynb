# %%
# !mkdir -p data screenshots
from google.colab import files
uploaded = files.upload()  # choose titanic.csv from your PC
import shutil, os
for fname in uploaded.keys():
    shutil.move(fname, "data/" + fname)
# !ls -la data
# Out:
#      <input type="file" id="files-e4882684-a829-4bf0-9ef4-9b94ccf89882" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e4882684-a829-4bf0-9ef4-9b94ccf89882">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# TASK 5 - DATA ANALYSIS

import pandas as pd
import matplotlib.pyplot as plt

# 1. Load CSV
df = pd.read_csv("data/sales.csv")
print("Column Names:")
print(df.columns)

# 2. Handle missing values
df = df.dropna()
print("\nAfter Removing Missing Values:", df.shape)

# 3. Display first rows
print("\nPreview of Dataset:")
print(df.head())

# 4. Total revenue
total_revenue = df["Total"].sum()
print("\nTotal Revenue:", total_revenue)

# 5. Category-wise Total Sales
category_sales = df.groupby("Category")["Total"].sum()
print("\nTotal Sales by Category:")
print(category_sales)

# 6. Product-wise Quantity Sold
product_qty = df.groupby("Product")["Quantity"].sum()
print("\nQuantity Sold by Product:")
print(product_qty)

# 7. Bar Plot – Category Sales
plt.figure(figsize=(6,4))
category_sales.plot(kind="bar")
plt.title("Total Sales by Category")
plt.xlabel("Category")
plt.ylabel("Sales")
plt.show()

# 8. Line Plot – Daily Sales Trend
daily_sales = df.groupby("Date")["Total"].sum()

plt.figure(figsize=(6,4))
daily_sales.plot(kind="line", marker="o")
plt.title("Daily Sales Trend")
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.show()
# Out:
# Column Names:
# Index(['OrderID', 'Product', 'Category', 'Quantity', 'Price', 'Total', 'Date'], dtype='object')
#
# After Removing Missing Values: (8, 7)
#
# Preview of Dataset:
#    OrderID     Product     Category  Quantity  Price  Total        Date
# 0     1001      Laptop  Electronics         1  75000  75000  2025-01-10
# 1     1002       Phone  Electronics         2  20000  40000  2025-01-11
# 2     1003      Tablet  Electronics         1  30000  30000  2025-01-11
# 3     1004      Laptop  Electronics         1  76000  76000  2025-01-12
# 4     1005  Headphones  Accessories         3   3000   9000  2025-01-13
#
# Total Revenue: 387000
#
# Total Sales by Category:
# Category
# Accessories      9000
# Electronics    378000
# Name: Total, dtype: int64
#
# Quantity Sold by Product:
# Product
# Headphones    3
# Laptop        3
# Phone         3
# Tablet        3
# Name: Quantity, dtype: int64
